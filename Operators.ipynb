# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasanta-ai/Data-Science/blob/main/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Operators

# %% [markdown]
# - **Adition**
# - **Subtraction**
# - **Multiplication**
# - **Exponent**

# %%
3 + 4
# Out:
# 7

# %%
4 - 6
# Out:
# -2

# %%
5 * 3
# Out:
# 15

# %%
16 / 5
# Out:
# 3.2

# %%
2 * 2 * 2
# Out:
# 8

# %%
2 ** 3
# Out:
# 8

# %%
(16 - (2 + (4 * (1 / 5))))
# Out:
# 13.2

# %%
num1 = 9
num2 = 8
num1 + num2
# Out:
# 17

# %%
total = num1 + num2

# %%
print(total)
# Out:
# 17

# %%
print("Data" + " Science")
# Out:
# Data Science

# %% [markdown]
# ## Comparison Operators

# %%
5 == 5
# Out:
# True

# %%
5 == 6
# Out:
# False

# %%
8 != 9
# Out:
# True

# %%
a = 5
b = 6
a == b
# Out:
# False

# %%
6 > 5
# Out:
# True

# %%
5 < 8
# Out:
# True

# %%
6 >= 4
# Out:
# True

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# - **AND**
# - **OR**
# - **NOT**

# %%
True and False
# Out:
# False

# %%
print(True and True)
print(True and False)
print(False and False)
# Out:
# True
# False
# False

# %%
print(True or True)
print(True or False)
print(False or False)
# Out:
# True
# True
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
5 < 6 and 6 < 5
# Out:
# False

# %% [markdown]
# ## Operator Precedence

# %% [markdown]
#                             NOT
#        AND                                          OR

# %%
not True and False or True
# Out:
# True
