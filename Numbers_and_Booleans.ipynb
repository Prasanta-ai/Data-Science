# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasanta-ai/Data-Science/blob/main/Numbers_and_Booleans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Number

# %% [markdown]
# ## Integer - int

# %%
a = 9
a
# Out:
# 9

# %% [markdown]
# ## Floating point - float

# %%
b = 9.5

# %% [markdown]
# - type()

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %% [markdown]
# ## Typecasting

# %%
divide = 7 / 2
print(divide)
# Out:
# 3.5

# %% [markdown]
# - int()
# - float()

# %%
float(a)
# Out:
# 9.0

# %%
int(divide)
# Out:
# 3

# %% [markdown]
# # Boolean

# %% [markdown]
# - True
# - False

# %%
r = True
s = False

# %%
print(type(r))
print(type(s))
# Out:
# <class 'bool'>
# <class 'bool'>
